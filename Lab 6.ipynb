# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhusam/Machine_Learning/blob/main/Lab%206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Dataset using for the project
dataframe_project = pd.read_csv(r'/content/Malayalam_Char_Gabor.csv')
dataframe_project
# Out:
#                                               ImageName  Label  \
# 0     3453_original_229a (3).png_1204e789-c4bc-488c-...   3453
# 1     3453_original_970a.png_80bfa285-9714-48c6-9bbb...   3453
# 2     3453_original_266a.png_4ac656bd-440f-41a2-929f...   3453
# 3     3453_original_2898a.png_cedc433e-d63c-453e-8df...   3453
# 4     3453_original_379a.png_bc94ae88-4af1-4375-91ce...   3453
# ...                                                 ...    ...
# 8142                                             57.png   3337
# 8143                                             50.png   3337
# 8144                                             81.png   3337
# 8145                                             76.png   3337
# 8146                                             46.png   3337
#
#       Theta0_Lambda1_LocalEnergy  Theta0_Lambda1_MeanAmplitude  \
# 0                          39752                         24995
# 1                          63716                         40885
# ...

# %%
# Replacing the Nan values if any
dataframe_project.replace('?', np.NaN, inplace = True)
dataframe_project
# Out:
#                                               ImageName  Label  \
# 0     3453_original_229a (3).png_1204e789-c4bc-488c-...   3453
# 1     3453_original_970a.png_80bfa285-9714-48c6-9bbb...   3453
# 2     3453_original_266a.png_4ac656bd-440f-41a2-929f...   3453
# 3     3453_original_2898a.png_cedc433e-d63c-453e-8df...   3453
# 4     3453_original_379a.png_bc94ae88-4af1-4375-91ce...   3453
# ...                                                 ...    ...
# 8142                                             57.png   3337
# 8143                                             50.png   3337
# 8144                                             81.png   3337
# 8145                                             76.png   3337
# 8146                                             46.png   3337
#
#       Theta0_Lambda1_LocalEnergy  Theta0_Lambda1_MeanAmplitude  \
# 0                          39752                         24995
# 1                          63716                         40885
# ...

# %%
# Finding the count of the null values
dataframe_project.isnull().sum()
# Out:
# ImageName                          0
# Label                              0
# Theta0_Lambda1_LocalEnergy         0
# Theta0_Lambda1_MeanAmplitude       0
# Theta0_Lambda0_LocalEnergy         0
# Theta0_Lambda0_MeanAmplitude       0
# Theta0_Lambda0_LocalEnergy.1       0
# Theta0_Lambda0_MeanAmplitude.1     0
# Theta0_Lambda0_LocalEnergy.2       0
# Theta0_Lambda0_MeanAmplitude.2     0
# Theta0_Lambda0_LocalEnergy.3       0
# Theta0_Lambda0_MeanAmplitude.3     0
# Theta1_Lambda1_LocalEnergy         0
# Theta1_Lambda1_MeanAmplitude       0
# Theta1_Lambda0_LocalEnergy         0
# Theta1_Lambda0_MeanAmplitude       0
# Theta1_Lambda0_LocalEnergy.1       0
# Theta1_Lambda0_MeanAmplitude.1     0
# Theta1_Lambda0_LocalEnergy.2       0
# Theta1_Lambda0_MeanAmplitude.2     0
# Theta1_Lambda0_LocalEnergy.3       0
# Theta1_Lambda0_MeanAmplitude.3     0
# Theta0_Lambda1_LocalEnergy.1       0
# Theta0_Lambda1_MeanAmplitude.1     0
# Theta0_Lambda0_LocalEnergy.4       0
# ...

# %%
# Question A1:
# Taking 2 attributes having real values and make a scatter plot out of it

attribute1 = dataframe_project['f0'] # Taking column f0 as the first real values attribute
attribute2 = dataframe_project['f190'] # Taking column f190 as the second real values attribute
print(attribute1)
print()
print(attribute2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'f0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Applying a scatter plot on the chosen attributes
plt.figure(figsize=(10, 10))
plt.scatter(attribute1, attribute2, color='green')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8315c8677948> in <cell line: 3>()
#       1 # Applying a scatter plot on the chosen attributes
#       2 plt.figure(figsize=(10, 10))
# ----> 3 plt.scatter(attribute1, attribute2, color='green')
#       4 plt.show()
#
# NameError: name 'attribute1' is not defined

# %%
# Question A2:
# Creating a linear regression model on the given data
from sklearn import linear_model
from sklearn.model_selection import train_test_split
attribute_independent = pd.DataFrame(attribute1) # Making the independent attribute
attribute_dependent = pd.DataFrame(attribute2) # Making the dependent attribute

# Splitting the data into training data and testing data
attribute_independent_train, attribute_independent_test, attribute_dependent_train, attribute_dependent_test = train_test_split(attribute_independent, attribute_dependent, test_size = 0.3, random_state = 42)
regressor = linear_model.LinearRegression()
# Fitting the training data into the model
regressor.fit(attribute_independent_train, attribute_dependent_train)
# Predicting the values using the input test data
attribute_dependent_pred = regressor.predict(attribute_independent_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fea89c054407> in <cell line: 5>()
#       3 from sklearn import linear_model
#       4 from sklearn.model_selection import train_test_split
# ----> 5 attribute_independent = pd.DataFrame(attribute1) # Making the independent attribute
#       6 attribute_dependent = pd.DataFrame(attribute2) # Making the dependent attribute
#       7
#
# NameError: name 'attribute1' is not defined

# %%
# Calculating the given model mean square error
from sklearn.metrics import mean_squared_error
mean_square_error_attribute = mean_squared_error(attribute_dependent_test, attribute_dependent_pred)
print("The mean square error of the given dataset is: ", mean_square_error_attribute)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9b634704f8d4> in <cell line: 3>()
#       1 # Calculating the given model mean square error
#       2 from sklearn.metrics import mean_squared_error
# ----> 3 mean_square_error_attribute = mean_squared_error(attribute_dependent_test, attribute_dependent_pred)
#       4 print("The mean square error of the given dataset is: ", mean_square_error_attribute)
#
# NameError: name 'attribute_dependent_test' is not defined
