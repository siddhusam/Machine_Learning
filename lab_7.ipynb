# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhusam/Machine_Learning/blob/main/lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dataframe_project = pd.read_csv(r'/content/Malayalam_Char_Gabor.csv')
dataframe_project
# Out:
#                                               ImageName  Label  \
# 0     3453_original_229a (3).png_1204e789-c4bc-488c-...   3453
# 1     3453_original_970a.png_80bfa285-9714-48c6-9bbb...   3453
# 2     3453_original_266a.png_4ac656bd-440f-41a2-929f...   3453
# 3     3453_original_2898a.png_cedc433e-d63c-453e-8df...   3453
# 4     3453_original_379a.png_bc94ae88-4af1-4375-91ce...   3453
# ...                                                 ...    ...
# 8142                                             57.png   3337
# 8143                                             50.png   3337
# 8144                                             81.png   3337
# 8145                                             76.png   3337
# 8146                                             46.png   3337
#
#       Theta0_Lambda1_LocalEnergy  Theta0_Lambda1_MeanAmplitude  \
# 0                          39752                         24995
# 1                          63716                         40885
# 2                          74632                         62911
# 3                          75036                         64182
# 4                          96639                         99048
# ...                          ...                           ...
# 8142                       72964                         51154
# 8143                       72964                         51154
# 8144                       91924                         68516
# 8145                      123488                        123131
# 8146                       74420                         68856
#
#       Theta0_Lambda0_LocalEnergy  Theta0_Lambda0_MeanAmplitude  \
# 0                          28698                         22220
# 1                          44338                         34134
# 2                          69469                         55907
# 3                          77137                         72890
# 4                         105117                        102279
# ...                          ...                           ...
# 8142                       54224                         35308
# 8143                       54224                         35308
# 8144                       74379                         43911
# 8145                      132974                        122304
# 8146                       74897                         57173
#
#       Theta0_Lambda0_LocalEnergy.1  Theta0_Lambda0_MeanAmplitude.1  \
# 0                            47492                           39752
# 1                            80364                           63716
# 2                            73178                           74632
# 3                            69444                           75036
# 4                            99693                           96639
# ...                            ...                             ...
# 8142                         86407                           72964
# 8143                         86407                           72964
# 8144                        107549                           91924
# 8145                        127872                          123488
# 8146                         71224                           74420
#
#       Theta0_Lambda0_LocalEnergy.2  Theta0_Lambda0_MeanAmplitude.2  ...  \
# 0                            24995                           28698  ...
# 1                            40885                           44338  ...
# 2                            62911                           69469  ...
# 3                            64182                           77137  ...
# 4                            99048                          105117  ...
# ...                            ...                             ...  ...
# 8142                         51154                           54224  ...
# 8143                         51154                           54224  ...
# 8144                         68516                           74379  ...
# 8145                        123131                          132974  ...
# 8146                         68856                           74897  ...
#
#       Theta0_Lambda1_LocalEnergy.3  Theta0_Lambda1_MeanAmplitude.3  \
# 0                          3504689                         3487904
# 1                          4916428                         4888272
# 2                          5481859                         5456359
# 3                          5181926                         5156425
# 4                          6160991                         6127856
# ...                            ...                             ...
# 8142                       5299603                         5266739
# 8143                       5299603                         5266739
# 8144                       5173680                         5132048
# 8145                       5918863                         5876614
# 8146                       5304386                         5275019
#
#       Theta0_Lambda0_LocalEnergy.12  Theta0_Lambda0_MeanAmplitude.12  \
# 0                           3468278                          1963883
# 1                           4851933                          2748641
# 2                           5412212                          3056522
# 3                           5110574                          2885396
# 4                           6062635                          3419058
# ...                             ...                              ...
# 8142                        5226140                          2960955
# 8143                        5226140                          2960955
# 8144                        5086101                          2884587
# 8145                        5792105                          3263922
# 8146                        5225564                          2952096
#
#       Theta0_Lambda0_LocalEnergy.13  Theta0_Lambda0_MeanAmplitude.13  \
# 0                           2072174                          3508397
# 1                           2900020                          4916784
# 2                           3225966                          5486808
# 3                           3045515                          5188801
# 4                           3609077                          6164290
# ...                             ...                              ...
# 8142                        3123975                          5305273
# 8143                        3123975                          5305273
# 8144                        3042920                          5186365
# 8145                        3445408                          5923742
# 8146                        3115525                          5308841
#
#       Theta0_Lambda0_LocalEnergy.14  Theta0_Lambda0_MeanAmplitude.14  \
# 0                           3491984                          3469319
# 1                           4888045                          4851383
# 2                           5462044                          5413867
# 3                           5164012                          5112495
# 4                           6132374                          6063669
# ...                             ...                              ...
# 8142                        5273262                          5227508
# 8143                        5273262                          5227508
# 8144                        5145728                          5088521
# 8145                        5882949                          5794078
# 8146                        5280518                          5227069
#
#       Theta0_Lambda0_LocalEnergy.15  Theta0_Lambda0_MeanAmplitude.15
# 0                           1962913                          2071265
# 1                           2748266                          2899613
# 2                           3054577                          3224056
# 3                           2882887                          3043039
# 4                           3417937                          3607999
# ...                             ...                              ...
# 8142                        2959129                          3122212
# 8143                        2959129                          3122212
# 8144                        2880923                          3039425
# 8145                        3262649                          3444197
# 8146                        2950375                          3113868
#
# [8147 rows x 52 columns]

# %%
# Question A1:
# Perform SVM on a biclass classification data and find their support vectors
from sklearn import svm
from sklearn.model_selection import train_test_split
input_dataframe = dataframe_project.loc[dataframe_project['Label']!=2, dataframe_project.columns[2:]]
output_dataframe = dataframe_project.loc[dataframe_project['Label']!=2, dataframe_project.columns[1]]

dataframe_input_train, dataframe_input_test, dataframe_output_train, dataframe_output_test = train_test_split(input_dataframe, output_dataframe, test_size=0.3, random_state=45)

machine = svm.SVC()
machine.fit(dataframe_input_train, dataframe_output_train)

machine.support_vectors_
# Out:
# array([[ 124081.,   80922.,   88614., ..., 6280219., 3563106., 3758439.],
#        [  73004.,   67328.,   77748., ..., 3888864., 2192613., 2314464.],
#        [ 132813.,  138191.,  143849., ..., 5923111., 3336000., 3521515.],
#        ...,
#        [  58783.,   37906.,   42153., ..., 4561724., 2583828., 2726188.],
#        [  32608.,   20022.,   22106., ..., 3363695., 1902455., 2007594.],
#        [  41302.,   35573.,   38109., ..., 3236458., 1825369., 1926846.]])

# %%
# Question A2:
# Test the accuracy of the SVM model

print("The accuracy of the support vector machine model is: ", machine.score(dataframe_input_test, dataframe_output_test))
# Out:
# The accuracy of the support vector machine model is:  0.14969325153374233

# %%
# Question A3:
# Predict a given input to a class value
print("For the corresponding vector the output is: ", machine.predict([input_dataframe.iloc[45, :]]))
# Out:
# For the corresponding vector the output is:  [3361]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
# Question A4:
# Train the data using different kernel functions
machine_poly = svm.SVC(kernel='poly')

machine_poly.fit(dataframe_input_train, dataframe_output_train)
print("The model using the polynomial function gives the accuracy of: ", machine_poly.score(dataframe_input_test, dataframe_output_test))
# Out:
# The model using the polynomial function gives the accuracy of:  0.13701431492842536

# %%
machine_rbf = svm.SVC(kernel='rbf')

machine_rbf.fit(dataframe_input_train, dataframe_output_train)
print("The model using the radial basis function gives the accuracy of: ", machine_rbf.score(dataframe_input_test, dataframe_output_test))
# Out:
# The model using the radial basis function gives the accuracy of:  0.14969325153374233

# %%
machine_sigmoid = svm.SVC(kernel='sigmoid')

machine_sigmoid.fit(dataframe_input_train, dataframe_output_train)
print("The model using the sigmoid function gives the accuracy of: ", machine_sigmoid.score(dataframe_input_test, dataframe_output_test))
# Out:
# The model using the sigmoid function gives the accuracy of:  0.04539877300613497

# %%
machine_linear = svm.SVC(kernel='linear')

machine_linear.fit(dataframe_input_train, dataframe_output_train)
print("The model using the linear function gives the accuracy of: ", machine_linear.score(dataframe_input_test, dataframe_output_test))
